# %%
import pandas as pd
Data = pd.read_csv('../data/SCMS_Delivery_History_Dataset_20150929 (2).csv', encoding="ISO-8859-1")
Data.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
col = Data["Line Item Value"]
df_selected2.insert(loc=9, column='Line Item Value', value=col)
import pandas as pd


colonnes_selectionnees = [
    'Line Item Value',
         
]

df_selected = Data[colonnes_selectionnees]

df_selected.head()
# Out:
#    Line Item Value
# 0            551.0
# 1           6200.0
# 2          40000.0
# 3         127360.8
# 4         121600.0

# %%
df = pd.read_csv('../data/SCMS_Delivery_History_Dataset1.csv', encoding="ISO-8859-1")
df.head()
# Out:
#    Line Item Quantity  Weight (Kilograms)  Freight Cost (USD)  Delayed  \
# 0                  19                13.0              780.34        0
# 1                1000               358.0             4521.50        0
# 2                 500               171.0             1653.78        0
# 3               31920              1855.0            16007.06        0
# 4               38000              7590.0            45450.08        0
#
#    Processing Time (Days)  Fulfill Via_Direct Drop  Shipment Mode_Air  \
# 0                    24.0                     True               True
# 1                    24.0                     True               True
# 2                    24.0                     True               True
# 3                    24.0                     True               True
# 4                    24.0                     True               True
#
#    Shipment Mode_Air Charter  Shipment Mode_Ocean  Shipment Mode_Truck  ...  \
# ...

# %%
import pandas as pd


colonnes_selectionnees2 = [
    'Weight (Kilograms)',
    'Freight Cost (USD)',
    'Processing Time (Days)',
    'Shipment Mode_Truck',
    'Country_Congo, DRC',
    'Country_CÃ´te d\'Ivoire',
    'Country_Mozambique',
    'Country_Uganda',
    'Country_Zambia',
    'Delivery Quarter_1',
    'Delivery Quarter_2',
    'Delivery Quarter_3',
    'Delivery Quarter_4',
    'Vendor_encoded',
    'Delayed'




]

df_selected2 = df[colonnes_selectionnees2]

df_selected2.head()
# Out:
#    Weight (Kilograms)  Freight Cost (USD)  Processing Time (Days)  \
# 0                13.0              780.34                    24.0
# 1               358.0             4521.50                    24.0
# 2               171.0             1653.78                    24.0
# 3              1855.0            16007.06                    24.0
# 4              7590.0            45450.08                    24.0
#
#    Shipment Mode_Truck  Country_Congo, DRC  Country_CÃ´te d'Ivoire  \
# 0                False               False                    True
# 1                False               False                   False
# 2                False               False                    True
# 3                False               False                   False
# 4                False               False                   False
#
#    Country_Mozambique  Country_Uganda  Country_Zambia  Delivery Quarter_1  \
# 0               False           False           False               False
# ...

# %%
col = Data["Line Item Value"]
df_selected2.drop(columns=['Line Item Value'], inplace=True)
df_selected2.insert(loc=0, column='Line Item Value', value=col)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_66876\4122052849.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected2.drop(columns=['Line Item Value'], inplace=True)

# %%
df_selected2.head()
# Out:
#    Line Item Value  Weight (Kilograms)  Freight Cost (USD)  \
# 0            551.0                13.0              780.34
# 1           6200.0               358.0             4521.50
# 2          40000.0               171.0             1653.78
# 3         127360.8              1855.0            16007.06
# 4         121600.0              7590.0            45450.08
#
#    Processing Time (Days)  Shipment Mode_Truck  Country_Congo, DRC  \
# 0                    24.0                False               False
# 1                    24.0                False               False
# 2                    24.0                False               False
# 3                    24.0                False               False
# 4                    24.0                False               False
#
#    Country_CÃ´te d'Ivoire  Country_Mozambique  Country_Uganda  Country_Zambia  \
# 0                    True               False           False           False
# ...

# %%
df_selected2.to_csv('../data/SCMS_selected_features.csv', index=False)
